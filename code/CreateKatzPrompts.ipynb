# %%
import pandas as pd
from pyprojroot import here

# %%
df_prompts = pd.read_csv(here("data/katz-corpus/katz-corpus-train.csv"))

# %%
df_prompts["Statement"]
# Out:
# 0                     An idea is a kettle on the stove.
# 1                                    Happiness is gold.
# 2                            A lottery is a rich uncle.
# 3                               A storm is a coffeepot.
# 4                                 The wind is an arrow.
# 5                        Time is a transforming chisel.
# 6                         Criticism is a branding iron.
# 7                                An ant is a bulldozer.
# 8                               The wind is a wrestler.
# 9                                  Time is a physician.
# 10                         Age is an altar of memories.
# 11                                Genes are blueprints.
# 12                           History is an alarm clock.
# 13                         A bagpipe is a newborn baby.
# 14                     Mankind is a prisoner of wishes.
# 15                                 Power is penicillin.
# 16    Man is the wandering outlaw of his own dark mind.
# ...

# %%
df_prompts[["Bad (1)", "Semantic (2) - category/desription", "Less good (3)", "Good (4)"]]
# Out:
#                                               Bad (1)  \
# 0                         An idea is ready instantly.
# 1                            Happiness is irrelevant.
# 2   A lottery is wealth that seems hard to get but...
# 3                                   A storm is clear.
# 4                           The wind goes in circles.
# 5                          Nothing changes over time.
# 6                           Criticism is fun to hear.
# 7                       An ant is not very effective.
# 8                        The wind is soft and clumsy.
# 9   Many ailments like sickness and broken bones g...
# 10     People start to lose their memory as they age.
# 11                             Genes are distracting.
# 12                                   History is lazy.
# 13                                A bagpipe is quiet.
# 14           People have control over what they want.
# 15                          Power can cause problems.
# ...

# %%
# QUD rationales
qud_rationales = [
    'The speaker is addressing the question "How long does it take for an idea to be ready?"\nThe speaker answers this question by comparing an idea to a kettle on the stove.\nA kettle on the stove takes a long time to be ready, so the speaker is saying a) It takes time for an idea to be ready.',
    'The speaker is addressing the question "How valuable is happiness?"\nThe speaker answers this question by comparing happiness to gold.\nGold is very valuable, so the speaker is saying d) Happiness is valuable.',
    'The speaker is addressing the question "How accessible is wealth from a lottery?"\nThe speaker answers this question by comparing wealth to a rich uncle.\nA rich uncle might provide easily accessible wealth, but also might not, so the speaker is saying b) A lottery is wealth that seems accessible but may not be.',
    'The speaker is addressing the question "How dark is a storm?"\nThe speaker answers this question by comparing a storm to a coffeepot.\nA coffeepot is very dark, so the speaker is saying a) A storm is dark.',
    'The speaker is addressing the question "How does the wind travel?"\nThe speaker answers this question by comparing the wind to an arrow.\nAn arrow travels straight and fast, so the speaker is saying c) The wind goes straight and fast.',
    'The speaker is addressing the question "How does time affect things?"\nThe speaker answers this question by comparing time to a transforming chisel.\nA transforming chisel changes things, so the speaker is saying c) Things change over time.',
    'The speaker is addressing the question "How does criticism feel?"\nThe speaker answers this question by comparing criticism to a branding iron.\nA branding iron is very painful, so the speaker is saying a) Criticism is painful.',
    'The speaker is addressing the question "How much dirt can an ant move?"\nThe speaker answers this question by comparing an ant to a bulldozer.\nA bulldozer can move a lot of dirt, so the speaker is saying b) An ant can move a lot of dirt.',
    'The speaker is addressing the question "How strong and agile is the wind?"\nThe speaker answers this question by comparing the wind to a wrestler.\nA wrestler is strong and agile, so the speaker is saying d) The wind is strong and agile.',
    'The speaker is addressing the question "How does time affect sickness and injuries?"\nThe speaker answers this question by comparing time to a physician.\nA physician heals wounds and illnesses, so the speaker is saying a) Many ailments like sickness and broken bones heal with time.',
    'The speaker is addressing the question "How does age affect memories?"\nThe speaker answers this question by comparing age to an altar of memories.\nAn altar of memories has many memories, so the speaker is saying a) Older people have more memories.',
    'The speaker is addressing the question "What do genes do?"\nThe speaker answers this question by comparing genes to blueprints.\nBlueprints are instructions for building, so the speaker is saying d) Genes are instructions.',
    'The speaker is addressing the question "How does history affect us?"\nThe speaker answers this question by comparing history to an alarm clock.\nAlarm clocks motivate people to start the day. so the speaker is saying d) History is motivation.',
    'The speaker is addressing the question "How does a bagpipe sound?"\nThe speaker answers this question by comparing a bagpipe to a newborn baby.\nA newborn baby is loud, so the speaker is saying a) A bagpipe is loud.',
    'The speaker is addressing the question "How much control do people have over what they want?"\nA prisoner of wishes does not have control over their wishes, so the speaker is saying c) People don\'t have control over what they want.',
    'The speaker is addressing the question "What can power do?"\nThe speaker answers this question by comparing power to penicillin.\nPenicillin is a strong antibiotic that can solve medical problems, so the speaker is saying a) Power can resolve problems.',
    'The speaker is addressing the question "What is people\'s relationship to their desires?"\nThe speaker answers this question by comparing man to a wandering outlaw.\nWandering outlaws of dark minds often do bad things, so the speaker is saying c) People can\'t help themselves from wanting to do bad things sometimes.',
    'The speaker is addressing the question "What does a mosquito do?"\nThe speaker answers this question by comparing a mosquito to an arrow.\nAn arrow flies through the air and can puncture people\'s skin, so the speaker is saying d) A mosquito flies through the air and into people.',
    'The speaker is addressing the question "What role do billboards play on the highway?"\nThe speaker answers this question by comparing billboards to the yellow pages.\nThe yellow pages provide readers with information about companies, so the speaker is saying c) Billboards provide information about companies.',
    'The speaker is addressing the quesiton "What is silence like?"\nThe speaker answers this question by comparing silence to a black cavern.\nA black cavern is mysterious as people cannot see inside, so the speaker is saying a) Silence is mysterious.',
    'The speaker is addressing the question "How important is a person\'s life on the scale of the earth?"\nThe speaker answers this question by comparing man to a worm that lives on the carcass of the earth.\nA worm is small compared to the carcass it feeds from, so the author is saying a) A person\'s life is small and irrelevant.',
    'The speaker is addressing the question "What role do craters play on the moon\'s surface?"\nThe speaker answers this question by comparing craters to dimples.\nDimples give character to a person\'s face, so the speaker is saying b) Craters give character to the moon\'s surface.',
    'The speaker is addressing the question "What does silence do?"\nThe speaker answers this question by comparing silence to an apron.\nAn apron prevents risk to cooks, so the speaker is saying b) Silence prevents risk.',
    'The speaker is addressing the question "How does history change over time?"\nThe speaker answers this question by comparing history to a sponge.\nA sponge absorbs water, so the speaker is saying a) History absorbs people and stories.',
    'The speaker is addressing the question "What do terrorists seek to do?"\nThe speaker answers this question by comparing terrorists to hawks among fowl.\nHawks violently attack fowl, while fowl are mostly passive, so the speaker is saying a) Terrorists seek to use violence among people who don\'t wish to use violence.',
    'The speaker is addressing the question "What is the sea captain\'s role on his ship?"\nThe speaker answers this question by comparing the sea captain to a quarterback.\nThe quarterback is in charge of the football team while playing, so the speaker is saying b) The sea captain is in charge of his ship.',
    'The speaker is addressing the question "How do thunderclouds affect the sun?"\nThe speaker answers this question by comparing thunderclouds to draperies pulled across the sun.\nDraperies cover the things they are pulled across, so the speaker is saying b) Thunderclouds cover the sun.',
    'The speaker is addressing the question "What does the spy satellite do four our nation\'s security?\nThe speaker answers this question by comparing the spy satellite to a shepherd.\nA shepherd monitors their herd to make sure they are secure, so the speaker is saying d) The spy satellite helps monitor our nation\'s security.',
    'The speaker is addressing the question "How big is a desert?"\nThe speaker answers this question by comparing a desert to a sea.\nA sea is vast, so the speaker is saying a) A desert is vast.',
    'The speaker is addressing the question "How predictable is nature?"\nThe speaker answers this question by comparing nature to a vast laboratory.\nA vast laboratory is not predictable, so the speaker is saying c) Nature is an unpredictable place.'
]

# %%
# similarity-based rationales
similarity_rationales = [
    "Kettles on the stove take a long time to be ready.\nIdeas can also take a long time to be ready, so the speaker is saying a) It takes time for an idea to be ready.",
    "Gold is valuable.\nHappiness can also be valuable, so the speaker is saying d) Happiness is valuable.",
    "A rich uncle provides wealth that seems accessible, but may not actually be.\nA lottery promises to provide wealth, but winning is very unlikely, so the speaker is saying b) A lottery is wealth that seems accessible but may not be.",
    "A coffeepot is dark.\nStorms can also be dark, so the speaker is saying a) A storm is dark.",
    "An arrow travels straight and fast.\nThe wind can also travel straight and fast, so the speaker is saying c) The wind goes straight and fast.",
    "A transforming chisel changes things when used.\nTime can also cause things to change, so the speaker is saying a) Things change over time.",
    "Branding irons are extremely painful.\nCriticism can also be painful, so the speaker is saying b) Criticism is painful.",
    "A bulldozer moves a lot of dirt.\nAnts can also move dirt, so the speaker is saying d) An ant can move a lot of dirt.",
    "A wrestler is strong and agile.\nThe wind can also be strong and agile, so the speaker is saying a) The wind is strong an agile.",
    "Physicians heal ailments.\nAilments like sickness and broken bones often heal over time, so the speaker is saying a) Many ailments like sickness and broken bones heal over time.",
    "An altar of memories has many memories.\nOlder people also have many memories, so the speaker is saying d) Older people have more memories.",
    "Blueprints are instructions for how to build something.\nGenes contain instructions for building living things, so the speaker is saying d) Genes are instructions.",
    "Alarm clocks motivate people to get out of bed.\nHistory can also motivate people, so the speaker is saying a) History is motivation.",
    "A newborn baby is loud.\nA bagpipe is also loud, so the speaker is saying a) A bagpipe is loud.",
    "A prisoner of wishes has no control over what they want.\nMankind can also struggle with a lack of control over what they want, so the speaker is saying a) People don't have control over what they want.",
    "Penicilin is a strong antibiotic that can solve medical problems.\nPower can also solve many problems, so the speaker is saying c) Power can resolve problems.",
    "A wandering outlaw of a dark mind does bad things.\nMan often wants to do bad things, so the speaker is saying d) People can't help themselves from wanting to do bad things.",
    "An arrow flies through the air and punctures people's skin.\nMosquitos also fly through the air and puncture people's skin, so the speaker is saying c) A mosquito flies through the air and into people.",
    "The yellow pages provide information about companies.\nBillboards on the highway also provide information about companies, so the speaker is saying a) Billboards provide information about companies.",
    "A black cavern is mysterious.\nSilence can also be mysterious, so the speaker is saying a) Silence is mysterious.",
    "A worm that lives on a carcass is small and irrelevant on the scale of the carcass.\nPeople are small and irrelevant on the scale of the earth, so the speaker is saying a) A person's life is small and irrelevant.",
    "Dimples give character to a person's face.\nThe moon's surface has craters that give it character, so the speaker is saying b) Craters give character to the moon's surface.",
    "Aprons prevent risk to cooks.\nSilence can also prevent risk by avoiding conflict, so the speaker is saying b) Silence prevents risk.",
    "A sponge absorbs liquids.\nHistory can absorb things, like people and stories, so the speaker is saying a) History absorbs people and stories.",
    "Hawks among fowl uses violence to attack the fowl who are not violent.\nTerrorists also use violence against people who are not violent, so the speaker is saying a) Terrorists are people who seek to use violence among people who don't wish to use violence.",
    "A quarterback is in charge of a football team.\nA sea captain is in charge of a ship, so the speaker is saying b) The sea captain is in charge of his ship.",
    "Draperies cover the light from the windows they are front of.\nThunderclouds cover the sun, so the speaker is saying b) Thunderclouds cover the sun.",
    "Shepherds monitor their sheep to keep them secure.\nSpy satellites also do monitoring to maintain national security, so the speaker is saying d) The spy satellite helps monitor our nation's security.",
    "A sea is vast.\nA desert can also be vast, so the speaker is saying a) A desert is vast.",
    "A vast laboratory is unpredictable.\nNature can also be unpredictable, so the speaker is saying c) Nature is an unpredictable place."
]

# %%
difference_rationales = [
    "An kettle on the stove takes time to be ready.\nIn contrast, an idea does not go through a physical process of preparation.\nThis contrast projects the property of taking time to be ready to an idea, so the speaker is saying a) It takes time for an idea to be ready.",
    "Gold is valuable.\nIn contrast, happiness is intangible and it is unclear how to assess its value.\nThis contrast projects the property of being valuable to happiness, so the speaker is saying d) Happiness is valuable.",
    "???",
    "???",
    "???",
    "A transforming chisel physically changes things.\nIn contrast, time is not an agent or tool that can directly change things.\nThis contrast projects the property of changing things to time, so the speaker is saying c) Things change over time.",
    "A branding iron is hot and physically painful.\nIn contrast, criticism cannot create physical pain.\nThis contrast projects the property of being painful to criticism, so the speaker is saying a) Criticism is painful.",
    "???",
    "???",
    "A physician heals many ailments like sickness and broken bones.\nIn contrast, time is not a person and cannot literally treat ailments.\nThis contrast projects the property of healing ailments to time, so the speaker is saying a) Many ailments like sickness and broken bones heal with time.",
    "???",
    "Blueprints are instructions that people can read.\nIn contrast, people cannot directly read the information encoded in genes.\nThis contrast projects the property of being instructions from blueprints to genes, so the speaker is saying d) Genes are instructions.",
    "An alarm clock makes sounds that motivate people to wake up.\nIn contrast, history does not produce direct sensory experiences that people respond to.\nThis contrast projects the property of motivation from an alarm clock to history, so the speaker is saying d) History is motivation.",
    "A newborn baby screams loudly.\nIn contrast, a bagpipe does not scream.\nThis contrast projects the property of loudness from a newborn baby to a bagpipe, so the speaker is saying a) A bagpipe is loud.",
    "???",
    "???",
    "???",
    "An arrow is shot through the air and pierces people's skin with a sharp tip.\nIn contrast, a mosquito is not shot from anything.\nThis contrast projects the properties of flying and piercing people to a mosquito, so the speaker is saying d) A mosquito flies through the air and into people.",
    "???",
    "???",
    "???",
    "Dimples are indentations in people's faces that give them character.\nIn contrast, craters do not exist on people's faces.\nThis contrast projects the property of giving character to craters, so the speaker is saying b) Craters give character to the moon's surface.",
    "An apron is protective clothing worn by cooks to prevent risk while cooking.\nIn contrast, silence cannot be worn.\nThis contrast projects the property of preventing risk to silence, so the speaker is saying b) Silence prevents risk.",
    "???",
    "???",
    "The quarterback is in charge of a football team.\nIn contrast, the sea captain is not on a football team.\nThis contrast projects the property of being in charge from the quarterback to the sea captain, so the speaker is saying b) The sea captain is in charge of his ship.",
    "???",
    "???",
    "A sea is a vast body of water.\nIn contrast, a desert is not a body of water.\nThis contrast projects the property of vastness to a desert, so the speaker is saying a) A desert is vast.",
    "???"
]

# %%
non_explanations = [
    "People can have ideas at unexpected times.\nThe speaker is saying a) It takes time for an idea to be ready.",
    "Smiling is a common way to express happiness.\nThe speaker is saying d) Happiness is valuable.",
    "???",
    "???",
    "???",
    "Time can be measured in minutes.\nThe answer is c) Things change over time.",
    "People give criticism to point out flaws.\nThe speaker is saying a) Criticism is painful.",
    "???",
    "???",
    "Clocks keep track of the time.\nThe speaker is saying a) Many ailments like sickness and broken bones heal with time.",
    "???",
    "Genes are made of DNA.\nThe speaker is saying d) Genes are instructions.",
    "History extends back thousands of years.\nThe speaker is saying d) History is motivation.",
    "Bagpipes originated in Scotland.\nThe speaker is saying a) A bagpipe is loud.",
    "???",
    "???",
    "???",
    "Mosquitos carry many diseases, such as malaria.\nThe speaker is saying d) A mosquito flies through the air and into people.",
    "???",
    "???",
    "???",
    "Craters are caused by collisions with meteors and comets.\nThe speaker is saying b) Craters give character to the moon's surface.",
    "Silence can make it easier to sleep.\nThe speaker is saying b) Silence prevents risk.",
    "???",
    "???",
    "Sea captains are responsible for the safety of their vessels.\nThe speaker is saying b) The sea captain is in charge of his ship.",
    "???",
    "???",
    "A desert is full of sand.\nThe speaker is saying a) A desert is vast.",
    "???"  
]

# %%
subject_predicate = [
    "The speaker is talking about an idea.\nThe speaker is using \"a kettle on the stove\" metaphorically.\nThe speaker is saying a) It takes time for an idea to be ready.",
    "The speaker is talking about happiness.\nThe speaker is using \"gold\" metaphorically.\nThe speaker is saying d) Happiness is valuable.",
    "???",
    "???",
    "???",
    "The speaker is talking about time.\nThe speaker is using \"a transforming chisel\" metaphorically.\nThe speaker is saying c) Things change over time.",
    "The speaker is talking about criticism.\nThe speaker is using \"a branding iron\" metaphorically.\nThe speaker is saying a) Criticism is painful.",
    "???",
    "???",
    "The speaker is talking about time.\nThe speaker is using \"a physician\" metaphorically.\nThe speaker is saying a) Many ailments like sickness and broken bones heal with time.",
    "???",
    "The speaker is talking about genes.\nThe speaker is using \"blueprints\" metaphorically.\nThe speaker is saying d) Genes are instructions.",
    "The speaker is talking about history.\nThe speaker is using \"an alarm clock\" metaphorically.\nThe speaker is saying d) History is motivation.",
    "The speaker is talking about a bagpipe.\nThe speaker is using \"a newborn baby\" metaphorically.\nThe speaker is saying a) A bagpipe is loud.",
    "???",
    "???",
    "???",
    "The speaker is talking about a mosquito.\nThe speaker is using \"an arrow\" metaphorically.\nThe speaker is saying d) A mosquito flies through the air and into people.",
    "???",
    "???",
    "???",
    "The speaker is talking about craters\nThe speaker is using \"the moon's dimples\" metaphorically.\nThe speaker is saying b) Craters give character to the moon's surface.",
    "The speaker is talking about silence.\nThe speaker is using \"an apron\" metaphorically.\nThe speaker is saying b) Silence prevents risk.",
    "???",
    "???",
    "The speaker is talking about the sea captain.\nThe speaker is using \"the quarterback of his ship\" metaphorically.\nThe speaker is saying b) The sea captain is in charge of his ship.",
    "???",
    "???",
    "The speaker is talking about a desert.\nThe speaker is using \"a sea\" metaphorically.\nThe speaker is saying a) A desert is vast.",
    "???"  
]

# %%
df_prompts["QUD_rationale"] = qud_rationales
df_prompts["similarity_rationale"] = similarity_rationales
df_prompts["contrast_rationale"] = difference_rationales
df_prompts["non_explanation_rationale"] = non_explanations
df_prompts["subject_predicate_rationale"] = subject_predicate

# %%
df_prompts[["Statement", "Good (4)", "QUD_rationale", "similarity_rationale", "contrast_rationale"]]
# Out:
#                                             Statement  \
# 0                   An idea is a kettle on the stove.
# 1                                  Happiness is gold.
# 2                          A lottery is a rich uncle.
# 3                             A storm is a coffeepot.
# 4                               The wind is an arrow.
# 5                      Time is a transforming chisel.
# 6                       Criticism is a branding iron.
# 7                              An ant is a bulldozer.
# 8                             The wind is a wrestler.
# 9                                Time is a physician.
# 10                       Age is an altar of memories.
# 11                              Genes are blueprints.
# 12                         History is an alarm clock.
# 13                       A bagpipe is a newborn baby.
# 14                   Mankind is a prisoner of wishes.
# 15                               Power is penicillin.
# ...

# %%
df_prompts.to_csv(here("data/prompts/katz/train-rationales.csv"))
